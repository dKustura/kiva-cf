# %%
# essentials
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# utilities
import codecs
import logging
import time
import tqdm

# visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt

# serialization
import pickle

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 30)

# %% [markdown]
# Load results:

# %%
result_1 = pickle.load(open("eval_results/result_1.p", "rb"))
result_2 = pickle.load(open("eval_results/result_2.p", "rb"))
result_3 = pickle.load(open("eval_results/result_3.p", "rb"))
result_4 = pickle.load(open("eval_results/result_4.p", "rb"))

# %%
scores_1 = result_1.mean(axis=0, level=['top-n', 'model'])
scores_2 = result_2.mean(axis=0, level=['top-n', 'model'])
scores_3 = result_3.mean(axis=0, level=['top-n', 'model'])
scores_4 = result_4.mean(axis=0, level=['top-n', 'model'])

# %% [markdown]
# ### F1 score function
# *F1 = 2 * (precision * recall) / (precision + recall)*

# %%
def f1_score(precision_series, recall_series):
    product = precision_series.multiply(recall_series).multiply(2)
    suma = precision_series.add(recall_series)
    return product / suma

# %% [markdown]
# ## Analysis of first results

# %% [markdown]
# Results:

# %%
precisions_1 = scores_1.xs('precision', level='metric', axis=1).unstack('model')
precisions_1
# Out:
# type                                                 relevance  \
# model ALS_rank-100_regularization-0.01_alpha-100_num_epochs-15
# top-n
# 5                                               0.002780
# 10                                              0.002198
# 20                                              0.001637
#
# type                                                            \
# model ALS_rank-100_regularization-0.01_alpha-100_num_epochs-30
# top-n
# 5                                               0.003280
# 10                                              0.002572
# 20                                              0.001981
#
# type                                                            \
# model ALS_rank-100_regularization-0.01_alpha-100_num_epochs-40
# top-n
# 5                                               0.003375
# 10                                              0.002698
# 20                                              0.002073
#
# type                                                          \
# model ALS_rank-100_regularization-0.01_alpha-1_num_epochs-15
# top-n
# 5                                               0.002814
# 10                                              0.002330
# 20                                              0.001833
#
# type                                                          \
# model ALS_rank-100_regularization-0.01_alpha-1_num_epochs-30
# top-n
# 5                                               0.002898
# 10                                              0.002398
# 20                                              0.001903
#
# type                                                          \
# model ALS_rank-100_regularization-0.01_alpha-1_num_epochs-40
# top-n
# 5                                               0.002958
# 10                                              0.002422
# 20                                              0.001900
#
# type                                                           \
# model ALS_rank-100_regularization-0.01_alpha-50_num_epochs-15
# top-n
# 5                                               0.003239
# 10                                              0.002531
# 20                                              0.001915
#
# type                                                           \
# model ALS_rank-100_regularization-0.01_alpha-50_num_epochs-30
# top-n
# 5                                               0.003386
# 10                                              0.002807
# 20                                              0.002172
#
# type                                                           \
# model ALS_rank-100_regularization-0.01_alpha-50_num_epochs-40
# top-n
# 5                                               0.003656
# 10                                              0.002915
# 20                                              0.002229
#
# type                                                           \
# model ALS_rank-100_regularization-0.1_alpha-100_num_epochs-15
# top-n
# 5                                               0.002614
# 10                                              0.002083
# 20                                              0.001583
#
# type                                                           \
# model ALS_rank-100_regularization-0.1_alpha-100_num_epochs-30
# top-n
# 5                                               0.003173
# 10                                              0.002506
# 20                                              0.001936
#
# type                                                           \
# model ALS_rank-100_regularization-0.1_alpha-100_num_epochs-40
# top-n
# 5                                               0.003297
# 10                                              0.002607
# 20                                              0.001986
#
# type                                                         \
# model ALS_rank-100_regularization-0.1_alpha-1_num_epochs-15
# top-n
# 5                                               0.002837
# 10                                              0.002339
# 20                                              0.001852
#
# type                                                         \
# model ALS_rank-100_regularization-0.1_alpha-1_num_epochs-30
# top-n
# 5                                               0.002900
# 10                                              0.002379
# 20                                              0.001881
#
# type                                                         \
# model ALS_rank-100_regularization-0.1_alpha-1_num_epochs-40
# top-n
# 5                                               0.002892
# 10                                              0.002405
# 20                                              0.001920
#
# type                                                          \
# model ALS_rank-100_regularization-0.1_alpha-50_num_epochs-15
# top-n
# 5                                               0.003097
# 10                                              0.002450
# 20                                              0.001867
#
# type                                                          \
# model ALS_rank-100_regularization-0.1_alpha-50_num_epochs-30
# top-n
# 5                                               0.003566
# 10                                              0.002843
# 20                                              0.002143
#
# type                                                          \
# model ALS_rank-100_regularization-0.1_alpha-50_num_epochs-40
# top-n
# 5                                               0.003640
# 10                                              0.002872
# 20                                              0.002226
#
# type                                                         \
# model ALS_rank-100_regularization-1_alpha-100_num_epochs-15
# top-n
# 5                                               0.002534
# 10                                              0.001912
# 20                                              0.001450
#
# type                                                         \
# model ALS_rank-100_regularization-1_alpha-100_num_epochs-30
# top-n
# 5                                               0.003152
# 10                                              0.002456
# 20                                              0.001856
#
# type                                                         \
# model ALS_rank-100_regularization-1_alpha-100_num_epochs-40
# top-n
# 5                                               0.003182
# 10                                              0.002549
# 20                                              0.001949
#
# type                                                       \
# model ALS_rank-100_regularization-1_alpha-1_num_epochs-15
# top-n
# 5                                               0.002845
# 10                                              0.002358
# 20                                              0.001866
#
# type                                                       \
# model ALS_rank-100_regularization-1_alpha-1_num_epochs-30
# top-n
# 5                                               0.002917
# 10                                              0.002410
# 20                                              0.001874
#
# type                                                       \
# model ALS_rank-100_regularization-1_alpha-1_num_epochs-40
# top-n
# 5                                               0.002964
# 10                                              0.002425
# 20                                              0.001893
#
# type                                                        \
# model ALS_rank-100_regularization-1_alpha-50_num_epochs-15
# top-n
# 5                                               0.003035
# 10                                              0.002372
# 20                                              0.001791
#
# type                                                        \
# model ALS_rank-100_regularization-1_alpha-50_num_epochs-30
# top-n
# 5                                               0.003380
# 10                                              0.002749
# 20                                              0.002091
#
# type                                                        \
# model ALS_rank-100_regularization-1_alpha-50_num_epochs-40
# top-n
# 5                                               0.003541
# 10                                              0.002823
# 20                                              0.002149
#
# type                                                           \
# model ALS_rank-10_regularization-0.01_alpha-100_num_epochs-15
# top-n
# 5                                               0.000605
# 10                                              0.000538
# 20                                              0.000476
#
# type                                                           \
# model ALS_rank-10_regularization-0.01_alpha-100_num_epochs-30
# top-n
# 5                                               0.000530
# 10                                              0.000601
# 20                                              0.000545
#
# type                                                           \
# model ALS_rank-10_regularization-0.01_alpha-100_num_epochs-40
# top-n
# 5                                               0.000549
# 10                                              0.000564
# 20                                              0.000540
#
# type                                                         \
# model ALS_rank-10_regularization-0.01_alpha-1_num_epochs-15
# top-n
# 5                                               0.000909
# 10                                              0.000959
# 20                                              0.000862
#
# type                                                         \
# model ALS_rank-10_regularization-0.01_alpha-1_num_epochs-30
# top-n
# 5                                               0.000958
# 10                                              0.000978
# 20                                              0.000875
#
# type                                                         \
# model ALS_rank-10_regularization-0.01_alpha-1_num_epochs-40
# top-n
# 5                                               0.000937
# 10                                              0.000971
# 20                                              0.000861
#
# type                                                          \
# model ALS_rank-10_regularization-0.01_alpha-50_num_epochs-15
# top-n
# 5                                               0.000708
# 10                                              0.000679
# 20                                              0.000608
#
# type                                                          \
# model ALS_rank-10_regularization-0.01_alpha-50_num_epochs-30
# top-n
# 5                                               0.000726
# 10                                              0.000706
# 20                                              0.000647
#
# type                                                          \
# model ALS_rank-10_regularization-0.01_alpha-50_num_epochs-40
# top-n
# 5                                               0.000808
# 10                                              0.000752
# 20                                              0.000633
#
# type                                                          \
# model ALS_rank-10_regularization-0.1_alpha-100_num_epochs-15
# top-n
# 5                                               0.000530
# 10                                              0.000505
# 20                                              0.000452
#
# type                                                          \
# model ALS_rank-10_regularization-0.1_alpha-100_num_epochs-30
# top-n
# 5                                               0.000572
# 10                                              0.000569
# 20                                              0.000532
#
# type                                                          \
# model ALS_rank-10_regularization-0.1_alpha-100_num_epochs-40
# top-n
# 5                                               0.000587
# 10                                              0.000582
# 20                                              0.000531
#
# type                                                        \
# model ALS_rank-10_regularization-0.1_alpha-1_num_epochs-15
# top-n
# 5                                               0.000917
# 10                                              0.000960
# 20                                              0.000852
#
# type                                                        \
# model ALS_rank-10_regularization-0.1_alpha-1_num_epochs-30
# top-n
# 5                                               0.001008
# 10                                              0.001005
# 20                                              0.000877
#
# type                                                        \
# model ALS_rank-10_regularization-0.1_alpha-1_num_epochs-40
# top-n
# 5                                               0.000906
# 10                                              0.000947
# 20                                              0.000862
#
# type                                                         \
# model ALS_rank-10_regularization-0.1_alpha-50_num_epochs-15
# top-n
# 5                                               0.000697
# 10                                              0.000636
# 20                                              0.000570
#
# type                                                         \
# model ALS_rank-10_regularization-0.1_alpha-50_num_epochs-30
# top-n
# 5                                               0.000769
# 10                                              0.000735
# 20                                              0.000645
#
# type                                                         \
# model ALS_rank-10_regularization-0.1_alpha-50_num_epochs-40
# top-n
# 5                                               0.000755
# 10                                              0.000736
# 20                                              0.000642
#
# type                                                        \
# model ALS_rank-10_regularization-1_alpha-100_num_epochs-15
# top-n
# 5                                               0.000604
# 10                                              0.000559
# 20                                              0.000476
#
# type                                                        \
# model ALS_rank-10_regularization-1_alpha-100_num_epochs-30
# top-n
# 5                                               0.000581
# 10                                              0.000577
# 20                                              0.000517
#
# type                                                        \
# model ALS_rank-10_regularization-1_alpha-100_num_epochs-40
# top-n
# 5                                               0.000561
# 10                                              0.000583
# 20                                              0.000537
#
# type                                                      \
# model ALS_rank-10_regularization-1_alpha-1_num_epochs-15
# top-n
# 5                                               0.000917
# 10                                              0.000964
# 20                                              0.000866
#
# type                                                      \
# model ALS_rank-10_regularization-1_alpha-1_num_epochs-30
# top-n
# 5                                               0.000947
# 10                                              0.000964
# 20                                              0.000868
#
# type                                                      \
# model ALS_rank-10_regularization-1_alpha-1_num_epochs-40
# top-n
# 5                                               0.000987
# 10                                              0.001006
# 20                                              0.000869
#
# type                                                       \
# model ALS_rank-10_regularization-1_alpha-50_num_epochs-15
# top-n
# 5                                               0.000666
# 10                                              0.000639
# 20                                              0.000562
#
# type                                                       \
# model ALS_rank-10_regularization-1_alpha-50_num_epochs-30
# top-n
# 5                                               0.000813
# 10                                              0.000743
# 20                                              0.000642
#
# type                                                       \
# model ALS_rank-10_regularization-1_alpha-50_num_epochs-40
# top-n
# 5                                               0.000722
# 10                                              0.000713
# 20                                              0.000648
#
# type                                                           \
# model ALS_rank-50_regularization-0.01_alpha-100_num_epochs-15
# top-n
# 5                                               0.001604
# 10                                              0.001335
# 20                                              0.001057
#
# type                                                           \
# model ALS_rank-50_regularization-0.01_alpha-100_num_epochs-30
# top-n
# 5                                               0.001871
# 10                                              0.001614
# 20                                              0.001270
#
# type                                                           \
# model ALS_rank-50_regularization-0.01_alpha-100_num_epochs-40
# top-n
# 5                                               0.002015
# 10                                              0.001676
# 20                                              0.001342
#
# type                                                         \
# model ALS_rank-50_regularization-0.01_alpha-1_num_epochs-15
# top-n
# 5                                               0.001749
# 10                                              0.001523
# 20                                              0.001261
#
# type                                                         \
# model ALS_rank-50_regularization-0.01_alpha-1_num_epochs-30
# top-n
# 5                                               0.001816
# 10                                              0.001569
# 20                                              0.001316
#
# type                                                         \
# model ALS_rank-50_regularization-0.01_alpha-1_num_epochs-40
# top-n
# 5                                               0.001835
# 10                                              0.001607
# 20                                              0.001286
#
# type                                                          \
# model ALS_rank-50_regularization-0.01_alpha-50_num_epochs-15
# top-n
# 5                                               0.001927
# 10                                              0.001599
# 20                                              0.001260
#
# type                                                          \
# model ALS_rank-50_regularization-0.01_alpha-50_num_epochs-30
# top-n
# 5                                               0.002151
# 10                                              0.001778
# 20                                              0.001434
#
# type                                                          \
# model ALS_rank-50_regularization-0.01_alpha-50_num_epochs-40
# top-n
# 5                                               0.002329
# 10                                              0.001892
# 20                                              0.001543
#
# type                                                          \
# model ALS_rank-50_regularization-0.1_alpha-100_num_epochs-15
# top-n
# 5                                               0.001531
# 10                                              0.001277
# 20                                              0.001017
#
# type                                                          \
# model ALS_rank-50_regularization-0.1_alpha-100_num_epochs-30
# top-n
# 5                                               0.001820
# 10                                              0.001544
# 20                                              0.001243
#
# type                                                          \
# model ALS_rank-50_regularization-0.1_alpha-100_num_epochs-40
# top-n
# 5                                               0.001935
# 10                                              0.001657
# 20                                              0.001338
#
# type                                                        \
# model ALS_rank-50_regularization-0.1_alpha-1_num_epochs-15
# top-n
# 5                                               0.001734
# 10                                              0.001503
# 20                                              0.001269
#
# type                                                        \
# model ALS_rank-50_regularization-0.1_alpha-1_num_epochs-30
# top-n
# 5                                               0.001829
# 10                                              0.001564
# 20                                              0.001329
#
# type                                                        \
# model ALS_rank-50_regularization-0.1_alpha-1_num_epochs-40
# top-n
# 5                                               0.001823
# 10                                              0.001571
# 20                                              0.001298
#
# type                                                         \
# model ALS_rank-50_regularization-0.1_alpha-50_num_epochs-15
# top-n
# 5                                               0.001884
# 10                                              0.001548
# 20                                              0.001255
#
# type                                                         \
# model ALS_rank-50_regularization-0.1_alpha-50_num_epochs-30
# top-n
# 5                                               0.002289
# 10                                              0.001908
# 20                                              0.001516
#
# type                                                         \
# model ALS_rank-50_regularization-0.1_alpha-50_num_epochs-40
# top-n
# 5                                               0.002404
# 10                                              0.001913
# 20                                              0.001518
#
# type                                                        \
# model ALS_rank-50_regularization-1_alpha-100_num_epochs-15
# top-n
# 5                                               0.001407
# 10                                              0.001186
# 20                                              0.000983
#
# type                                                        \
# model ALS_rank-50_regularization-1_alpha-100_num_epochs-30
# top-n
# 5                                               0.001953
# 10                                              0.001565
# 20                                              0.001252
#
# type                                                        \
# model ALS_rank-50_regularization-1_alpha-100_num_epochs-40
# top-n
# 5                                               0.001988
# 10                                              0.001657
# 20                                              0.001341
#
# type                                                      \
# model ALS_rank-50_regularization-1_alpha-1_num_epochs-15
# top-n
# 5                                               0.001748
# 10                                              0.001539
# 20                                              0.001270
#
# type                                                      \
# model ALS_rank-50_regularization-1_alpha-1_num_epochs-30
# top-n
# 5                                               0.001834
# 10                                              0.001566
# 20                                              0.001302
#
# type                                                      \
# model ALS_rank-50_regularization-1_alpha-1_num_epochs-40
# top-n
# 5                                               0.001740
# 10                                              0.001542
# 20                                              0.001302
#
# type                                                       \
# model ALS_rank-50_regularization-1_alpha-50_num_epochs-15
# top-n
# 5                                               0.001926
# 10                                              0.001564
# 20                                              0.001251
#
# type                                                       \
# model ALS_rank-50_regularization-1_alpha-50_num_epochs-30
# top-n
# 5                                               0.002197
# 10                                              0.001811
# 20                                              0.001453
#
# type                                                                           \
# model ALS_rank-50_regularization-1_alpha-50_num_epochs-40        MP   PureSVD
# top-n
# 5                                               0.002313   0.001156  0.001158
# 10                                              0.001884   0.000841  0.000883
# 20                                              0.001502   0.000909  0.000648
#
# type
# model       RND
# top-n
# 5      0.000012
# 10     0.000011
# 20     0.000014

# %%
recalls_1 = scores_1.xs('recall', level='metric', axis=1).unstack('model')
recalls_1
# Out:
# type                                                 relevance  \
# model ALS_rank-100_regularization-0.01_alpha-100_num_epochs-15
# top-n
# 5                                               0.004633
# 10                                              0.007326
# 20                                              0.010914
#
# type                                                            \
# model ALS_rank-100_regularization-0.01_alpha-100_num_epochs-30
# top-n
# 5                                               0.005467
# 10                                              0.008574
# 20                                              0.013206
#
# type                                                            \
# model ALS_rank-100_regularization-0.01_alpha-100_num_epochs-40
# top-n
# 5                                               0.005626
# 10                                              0.008992
# 20                                              0.013819
#
# type                                                          \
# model ALS_rank-100_regularization-0.01_alpha-1_num_epochs-15
# top-n
# 5                                               0.004690
# 10                                              0.007767
# 20                                              0.012220
#
# type                                                          \
# model ALS_rank-100_regularization-0.01_alpha-1_num_epochs-30
# top-n
# 5                                               0.004829
# 10                                              0.007994
# 20                                              0.012687
#
# type                                                          \
# model ALS_rank-100_regularization-0.01_alpha-1_num_epochs-40
# top-n
# 5                                               0.004930
# 10                                              0.008072
# 20                                              0.012664
#
# type                                                           \
# model ALS_rank-100_regularization-0.01_alpha-50_num_epochs-15
# top-n
# 5                                               0.005399
# 10                                              0.008437
# 20                                              0.012767
#
# type                                                           \
# model ALS_rank-100_regularization-0.01_alpha-50_num_epochs-30
# top-n
# 5                                               0.005644
# 10                                              0.009358
# 20                                              0.014482
#
# type                                                           \
# model ALS_rank-100_regularization-0.01_alpha-50_num_epochs-40
# top-n
# 5                                               0.006093
# 10                                              0.009716
# 20                                              0.014863
#
# type                                                           \
# model ALS_rank-100_regularization-0.1_alpha-100_num_epochs-15
# top-n
# 5                                               0.004357
# 10                                              0.006945
# 20                                              0.010553
#
# type                                                           \
# model ALS_rank-100_regularization-0.1_alpha-100_num_epochs-30
# top-n
# 5                                               0.005289
# 10                                              0.008352
# 20                                              0.012906
#
# type                                                           \
# model ALS_rank-100_regularization-0.1_alpha-100_num_epochs-40
# top-n
# 5                                               0.005495
# 10                                              0.008689
# 20                                              0.013239
#
# type                                                         \
# model ALS_rank-100_regularization-0.1_alpha-1_num_epochs-15
# top-n
# 5                                               0.004728
# 10                                              0.007797
# 20                                              0.012349
#
# type                                                         \
# model ALS_rank-100_regularization-0.1_alpha-1_num_epochs-30
# top-n
# 5                                               0.004834
# 10                                              0.007931
# 20                                              0.012538
#
# type                                                         \
# model ALS_rank-100_regularization-0.1_alpha-1_num_epochs-40
# top-n
# 5                                               0.004819
# 10                                              0.008017
# 20                                              0.012797
#
# type                                                          \
# model ALS_rank-100_regularization-0.1_alpha-50_num_epochs-15
# top-n
# 5                                               0.005162
# 10                                              0.008165
# 20                                              0.012444
#
# type                                                          \
# model ALS_rank-100_regularization-0.1_alpha-50_num_epochs-30
# top-n
# 5                                               0.005944
# 10                                              0.009477
# 20                                              0.014288
#
# type                                                          \
# model ALS_rank-100_regularization-0.1_alpha-50_num_epochs-40
# top-n
# 5                                               0.006067
# 10                                              0.009573
# 20                                              0.014842
#
# type                                                         \
# model ALS_rank-100_regularization-1_alpha-100_num_epochs-15
# top-n
# 5                                               0.004224
# 10                                              0.006372
# 20                                              0.009666
#
# type                                                         \
# model ALS_rank-100_regularization-1_alpha-100_num_epochs-30
# top-n
# 5                                               0.005253
# 10                                              0.008186
# 20                                              0.012374
#
# type                                                         \
# model ALS_rank-100_regularization-1_alpha-100_num_epochs-40
# top-n
# 5                                               0.005303
# 10                                              0.008495
# 20                                              0.012992
#
# type                                                       \
# model ALS_rank-100_regularization-1_alpha-1_num_epochs-15
# top-n
# 5                                               0.004741
# 10                                              0.007860
# 20                                              0.012442
#
# type                                                       \
# model ALS_rank-100_regularization-1_alpha-1_num_epochs-30
# top-n
# 5                                               0.004862
# 10                                              0.008032
# 20                                              0.012495
#
# type                                                       \
# model ALS_rank-100_regularization-1_alpha-1_num_epochs-40
# top-n
# 5                                               0.004940
# 10                                              0.008082
# 20                                              0.012621
#
# type                                                        \
# model ALS_rank-100_regularization-1_alpha-50_num_epochs-15
# top-n
# 5                                               0.005059
# 10                                              0.007906
# 20                                              0.011943
#
# type                                                        \
# model ALS_rank-100_regularization-1_alpha-50_num_epochs-30
# top-n
# 5                                               0.005634
# 10                                              0.009164
# 20                                              0.013937
#
# type                                                        \
# model ALS_rank-100_regularization-1_alpha-50_num_epochs-40
# top-n
# 5                                               0.005901
# 10                                              0.009409
# 20                                              0.014326
#
# type                                                           \
# model ALS_rank-10_regularization-0.01_alpha-100_num_epochs-15
# top-n
# 5                                               0.001009
# 10                                              0.001793
# 20                                              0.003175
#
# type                                                           \
# model ALS_rank-10_regularization-0.01_alpha-100_num_epochs-30
# top-n
# 5                                               0.000883
# 10                                              0.002005
# 20                                              0.003631
#
# type                                                           \
# model ALS_rank-10_regularization-0.01_alpha-100_num_epochs-40
# top-n
# 5                                               0.000915
# 10                                              0.001879
# 20                                              0.003603
#
# type                                                         \
# model ALS_rank-10_regularization-0.01_alpha-1_num_epochs-15
# top-n
# 5                                               0.001516
# 10                                              0.003198
# 20                                              0.005750
#
# type                                                         \
# model ALS_rank-10_regularization-0.01_alpha-1_num_epochs-30
# top-n
# 5                                               0.001597
# 10                                              0.003261
# 20                                              0.005836
#
# type                                                         \
# model ALS_rank-10_regularization-0.01_alpha-1_num_epochs-40
# top-n
# 5                                               0.001561
# 10                                              0.003236
# 20                                              0.005742
#
# type                                                          \
# model ALS_rank-10_regularization-0.01_alpha-50_num_epochs-15
# top-n
# 5                                               0.001180
# 10                                              0.002262
# 20                                              0.004050
#
# type                                                          \
# model ALS_rank-10_regularization-0.01_alpha-50_num_epochs-30
# top-n
# 5                                               0.001211
# 10                                              0.002353
# 20                                              0.004315
#
# type                                                          \
# model ALS_rank-10_regularization-0.01_alpha-50_num_epochs-40
# top-n
# 5                                               0.001347
# 10                                              0.002507
# 20                                              0.004221
#
# type                                                          \
# model ALS_rank-10_regularization-0.1_alpha-100_num_epochs-15
# top-n
# 5                                               0.000883
# 10                                              0.001682
# 20                                              0.003010
#
# type                                                          \
# model ALS_rank-10_regularization-0.1_alpha-100_num_epochs-30
# top-n
# 5                                               0.000953
# 10                                              0.001897
# 20                                              0.003549
#
# type                                                          \
# model ALS_rank-10_regularization-0.1_alpha-100_num_epochs-40
# top-n
# 5                                               0.000978
# 10                                              0.001939
# 20                                              0.003543
#
# type                                                        \
# model ALS_rank-10_regularization-0.1_alpha-1_num_epochs-15
# top-n
# 5                                               0.001528
# 10                                              0.003201
# 20                                              0.005682
#
# type                                                        \
# model ALS_rank-10_regularization-0.1_alpha-1_num_epochs-30
# top-n
# 5                                               0.001680
# 10                                              0.003349
# 20                                              0.005846
#
# type                                                        \
# model ALS_rank-10_regularization-0.1_alpha-1_num_epochs-40
# top-n
# 5                                               0.001511
# 10                                              0.003158
# 20                                              0.005745
#
# type                                                         \
# model ALS_rank-10_regularization-0.1_alpha-50_num_epochs-15
# top-n
# 5                                               0.001162
# 10                                              0.002121
# 20                                              0.003798
#
# type                                                         \
# model ALS_rank-10_regularization-0.1_alpha-50_num_epochs-30
# top-n
# 5                                               0.001281
# 10                                              0.002451
# 20                                              0.004302
#
# type                                                         \
# model ALS_rank-10_regularization-0.1_alpha-50_num_epochs-40
# top-n
# 5                                               0.001258
# 10                                              0.002453
# 20                                              0.004279
#
# type                                                        \
# model ALS_rank-10_regularization-1_alpha-100_num_epochs-15
# top-n
# 5                                               0.001006
# 10                                              0.001864
# 20                                              0.003170
#
# type                                                        \
# model ALS_rank-10_regularization-1_alpha-100_num_epochs-30
# top-n
# 5                                               0.000968
# 10                                              0.001924
# 20                                              0.003447
#
# type                                                        \
# model ALS_rank-10_regularization-1_alpha-100_num_epochs-40
# top-n
# 5                                               0.000935
# 10                                              0.001942
# 20                                              0.003583
#
# type                                                      \
# model ALS_rank-10_regularization-1_alpha-1_num_epochs-15
# top-n
# 5                                               0.001528
# 10                                              0.003213
# 20                                              0.005773
#
# type                                                      \
# model ALS_rank-10_regularization-1_alpha-1_num_epochs-30
# top-n
# 5                                               0.001579
# 10                                              0.003213
# 20                                              0.005785
#
# type                                                      \
# model ALS_rank-10_regularization-1_alpha-1_num_epochs-40
# top-n
# 5                                               0.001644
# 10                                              0.003354
# 20                                              0.005796
#
# type                                                       \
# model ALS_rank-10_regularization-1_alpha-50_num_epochs-15
# top-n
# 5                                               0.001110
# 10                                              0.002129
# 20                                              0.003748
#
# type                                                       \
# model ALS_rank-10_regularization-1_alpha-50_num_epochs-30
# top-n
# 5                                               0.001354
# 10                                              0.002476
# 20                                              0.004280
#
# type                                                       \
# model ALS_rank-10_regularization-1_alpha-50_num_epochs-40
# top-n
# 5                                               0.001203
# 10                                              0.002378
# 20                                              0.004322
#
# type                                                           \
# model ALS_rank-50_regularization-0.01_alpha-100_num_epochs-15
# top-n
# 5                                               0.002673
# 10                                              0.004448
# 20                                              0.007046
#
# type                                                           \
# model ALS_rank-50_regularization-0.01_alpha-100_num_epochs-30
# top-n
# 5                                               0.003119
# 10                                              0.005381
# 20                                              0.008465
#
# type                                                           \
# model ALS_rank-50_regularization-0.01_alpha-100_num_epochs-40
# top-n
# 5                                               0.003359
# 10                                              0.005585
# 20                                              0.008949
#
# type                                                         \
# model ALS_rank-50_regularization-0.01_alpha-1_num_epochs-15
# top-n
# 5                                               0.002915
# 10                                              0.005076
# 20                                              0.008405
#
# type                                                         \
# model ALS_rank-50_regularization-0.01_alpha-1_num_epochs-30
# top-n
# 5                                               0.003026
# 10                                              0.005230
# 20                                              0.008771
#
# type                                                         \
# model ALS_rank-50_regularization-0.01_alpha-1_num_epochs-40
# top-n
# 5                                               0.003059
# 10                                              0.005356
# 20                                              0.008577
#
# type                                                          \
# model ALS_rank-50_regularization-0.01_alpha-50_num_epochs-15
# top-n
# 5                                               0.003212
# 10                                              0.005331
# 20                                              0.008399
#
# type                                                          \
# model ALS_rank-50_regularization-0.01_alpha-50_num_epochs-30
# top-n
# 5                                               0.003586
# 10                                              0.005926
# 20                                              0.009563
#
# type                                                          \
# model ALS_rank-50_regularization-0.01_alpha-50_num_epochs-40
# top-n
# 5                                               0.003881
# 10                                              0.006307
# 20                                              0.010289
#
# type                                                          \
# model ALS_rank-50_regularization-0.1_alpha-100_num_epochs-15
# top-n
# 5                                               0.002552
# 10                                              0.004257
# 20                                              0.006779
#
# type                                                          \
# model ALS_rank-50_regularization-0.1_alpha-100_num_epochs-30
# top-n
# 5                                               0.003033
# 10                                              0.005147
# 20                                              0.008286
#
# type                                                          \
# model ALS_rank-50_regularization-0.1_alpha-100_num_epochs-40
# top-n
# 5                                               0.003225
# 10                                              0.005525
# 20                                              0.008917
#
# type                                                        \
# model ALS_rank-50_regularization-0.1_alpha-1_num_epochs-15
# top-n
# 5                                               0.002890
# 10                                              0.005009
# 20                                              0.008459
#
# type                                                        \
# model ALS_rank-50_regularization-0.1_alpha-1_num_epochs-30
# top-n
# 5                                               0.003049
# 10                                              0.005212
# 20                                              0.008859
#
# type                                                        \
# model ALS_rank-50_regularization-0.1_alpha-1_num_epochs-40
# top-n
# 5                                               0.003039
# 10                                              0.005238
# 20                                              0.008654
#
# type                                                         \
# model ALS_rank-50_regularization-0.1_alpha-50_num_epochs-15
# top-n
# 5                                               0.003139
# 10                                              0.005159
# 20                                              0.008367
#
# type                                                         \
# model ALS_rank-50_regularization-0.1_alpha-50_num_epochs-30
# top-n
# 5                                               0.003815
# 10                                              0.006360
# 20                                              0.010109
#
# type                                                         \
# model ALS_rank-50_regularization-0.1_alpha-50_num_epochs-40
# top-n
# 5                                               0.004007
# 10                                              0.006377
# 20                                              0.010120
#
# type                                                        \
# model ALS_rank-50_regularization-1_alpha-100_num_epochs-15
# top-n
# 5                                               0.002345
# 10                                              0.003954
# 20                                              0.006551
#
# type                                                        \
# model ALS_rank-50_regularization-1_alpha-100_num_epochs-30
# top-n
# 5                                               0.003256
# 10                                              0.005215
# 20                                              0.008350
#
# type                                                        \
# model ALS_rank-50_regularization-1_alpha-100_num_epochs-40
# top-n
# 5                                               0.003313
# 10                                              0.005525
# 20                                              0.008937
#
# type                                                      \
# model ALS_rank-50_regularization-1_alpha-1_num_epochs-15
# top-n
# 5                                               0.002913
# 10                                              0.005129
# 20                                              0.008468
#
# type                                                      \
# model ALS_rank-50_regularization-1_alpha-1_num_epochs-30
# top-n
# 5                                               0.003057
# 10                                              0.005221
# 20                                              0.008680
#
# type                                                      \
# model ALS_rank-50_regularization-1_alpha-1_num_epochs-40
# top-n
# 5                                               0.002900
# 10                                              0.005139
# 20                                              0.008680
#
# type                                                       \
# model ALS_rank-50_regularization-1_alpha-50_num_epochs-15
# top-n
# 5                                               0.003210
# 10                                              0.005212
# 20                                              0.008339
#
# type                                                       \
# model ALS_rank-50_regularization-1_alpha-50_num_epochs-30
# top-n
# 5                                               0.003662
# 10                                              0.006037
# 20                                              0.009683
#
# type                                                                           \
# model ALS_rank-50_regularization-1_alpha-50_num_epochs-40        MP   PureSVD
# top-n
# 5                                               0.003856   0.001927  0.001929
# 10                                              0.006279   0.002804  0.002943
# 20                                              0.010014   0.006063  0.004323
#
# type
# model       RND
# top-n
# 5      0.000020
# 10     0.000038
# 20     0.000093

# %%
f1_scores_1 = f1_score(precisions_1, recalls_1)
f1_scores_1
# Out:
# type                                                 relevance  \
# model ALS_rank-100_regularization-0.01_alpha-100_num_epochs-15
# top-n
# 5                                               0.003474
# 10                                              0.003381
# 20                                              0.002847
#
# type                                                            \
# model ALS_rank-100_regularization-0.01_alpha-100_num_epochs-30
# top-n
# 5                                               0.004101
# 10                                              0.003957
# 20                                              0.003445
#
# type                                                            \
# model ALS_rank-100_regularization-0.01_alpha-100_num_epochs-40
# top-n
# 5                                               0.004219
# 10                                              0.004150
# 20                                              0.003605
#
# type                                                          \
# model ALS_rank-100_regularization-0.01_alpha-1_num_epochs-15
# top-n
# 5                                               0.003518
# 10                                              0.003585
# 20                                              0.003188
#
# type                                                          \
# model ALS_rank-100_regularization-0.01_alpha-1_num_epochs-30
# top-n
# 5                                               0.003622
# 10                                              0.003690
# 20                                              0.003310
#
# type                                                          \
# model ALS_rank-100_regularization-0.01_alpha-1_num_epochs-40
# top-n
# 5                                               0.003698
# 10                                              0.003726
# 20                                              0.003304
#
# type                                                           \
# model ALS_rank-100_regularization-0.01_alpha-50_num_epochs-15
# top-n
# 5                                               0.004049
# 10                                              0.003894
# 20                                              0.003331
#
# type                                                           \
# model ALS_rank-100_regularization-0.01_alpha-50_num_epochs-30
# top-n
# 5                                               0.004233
# 10                                              0.004319
# 20                                              0.003778
#
# type                                                           \
# model ALS_rank-100_regularization-0.01_alpha-50_num_epochs-40
# top-n
# 5                                               0.004570
# 10                                              0.004484
# 20                                              0.003877
#
# type                                                           \
# model ALS_rank-100_regularization-0.1_alpha-100_num_epochs-15
# top-n
# 5                                               0.003268
# 10                                              0.003205
# 20                                              0.002753
#
# type                                                           \
# model ALS_rank-100_regularization-0.1_alpha-100_num_epochs-30
# top-n
# 5                                               0.003967
# 10                                              0.003855
# 20                                              0.003367
#
# type                                                           \
# model ALS_rank-100_regularization-0.1_alpha-100_num_epochs-40
# top-n
# 5                                               0.004121
# 10                                              0.004011
# 20                                              0.003454
#
# type                                                         \
# model ALS_rank-100_regularization-0.1_alpha-1_num_epochs-15
# top-n
# 5                                               0.003546
# 10                                              0.003599
# 20                                              0.003221
#
# type                                                         \
# model ALS_rank-100_regularization-0.1_alpha-1_num_epochs-30
# top-n
# 5                                               0.003626
# 10                                              0.003660
# 20                                              0.003271
#
# type                                                         \
# model ALS_rank-100_regularization-0.1_alpha-1_num_epochs-40
# top-n
# 5                                               0.003614
# 10                                              0.003700
# 20                                              0.003338
#
# type                                                          \
# model ALS_rank-100_regularization-0.1_alpha-50_num_epochs-15
# top-n
# 5                                               0.003871
# 10                                              0.003768
# 20                                              0.003246
#
# type                                                          \
# model ALS_rank-100_regularization-0.1_alpha-50_num_epochs-30
# top-n
# 5                                               0.004458
# 10                                              0.004374
# 20                                              0.003727
#
# type                                                          \
# model ALS_rank-100_regularization-0.1_alpha-50_num_epochs-40
# top-n
# 5                                               0.004551
# 10                                              0.004418
# 20                                              0.003872
#
# type                                                         \
# model ALS_rank-100_regularization-1_alpha-100_num_epochs-15
# top-n
# 5                                               0.003168
# 10                                              0.002941
# 20                                              0.002522
#
# type                                                         \
# model ALS_rank-100_regularization-1_alpha-100_num_epochs-30
# top-n
# 5                                               0.003940
# 10                                              0.003778
# 20                                              0.003228
#
# type                                                         \
# model ALS_rank-100_regularization-1_alpha-100_num_epochs-40
# top-n
# 5                                               0.003977
# 10                                              0.003921
# 20                                              0.003389
#
# type                                                       \
# model ALS_rank-100_regularization-1_alpha-1_num_epochs-15
# top-n
# 5                                               0.003556
# 10                                              0.003628
# 20                                              0.003246
#
# type                                                       \
# model ALS_rank-100_regularization-1_alpha-1_num_epochs-30
# top-n
# 5                                               0.003647
# 10                                              0.003707
# 20                                              0.003259
#
# type                                                       \
# model ALS_rank-100_regularization-1_alpha-1_num_epochs-40
# top-n
# 5                                               0.003705
# 10                                              0.003730
# 20                                              0.003293
#
# type                                                        \
# model ALS_rank-100_regularization-1_alpha-50_num_epochs-15
# top-n
# 5                                               0.003794
# 10                                              0.003649
# 20                                              0.003116
#
# type                                                        \
# model ALS_rank-100_regularization-1_alpha-50_num_epochs-30
# top-n
# 5                                               0.004225
# 10                                              0.004230
# 20                                              0.003636
#
# type                                                        \
# model ALS_rank-100_regularization-1_alpha-50_num_epochs-40
# top-n
# 5                                               0.004426
# 10                                              0.004343
# 20                                              0.003737
#
# type                                                           \
# model ALS_rank-10_regularization-0.01_alpha-100_num_epochs-15
# top-n
# 5                                               0.000757
# 10                                              0.000828
# 20                                              0.000828
#
# type                                                           \
# model ALS_rank-10_regularization-0.01_alpha-100_num_epochs-30
# top-n
# 5                                               0.000662
# 10                                              0.000925
# 20                                              0.000947
#
# type                                                           \
# model ALS_rank-10_regularization-0.01_alpha-100_num_epochs-40
# top-n
# 5                                               0.000686
# 10                                              0.000867
# 20                                              0.000940
#
# type                                                         \
# model ALS_rank-10_regularization-0.01_alpha-1_num_epochs-15
# top-n
# 5                                               0.001137
# 10                                              0.001476
# 20                                              0.001500
#
# type                                                         \
# model ALS_rank-10_regularization-0.01_alpha-1_num_epochs-30
# top-n
# 5                                               0.001197
# 10                                              0.001505
# 20                                              0.001522
#
# type                                                         \
# model ALS_rank-10_regularization-0.01_alpha-1_num_epochs-40
# top-n
# 5                                               0.001171
# 10                                              0.001493
# 20                                              0.001498
#
# type                                                          \
# model ALS_rank-10_regularization-0.01_alpha-50_num_epochs-15
# top-n
# 5                                               0.000885
# 10                                              0.001044
# 20                                              0.001057
#
# type                                                          \
# model ALS_rank-10_regularization-0.01_alpha-50_num_epochs-30
# top-n
# 5                                               0.000908
# 10                                              0.001086
# 20                                              0.001126
#
# type                                                          \
# model ALS_rank-10_regularization-0.01_alpha-50_num_epochs-40
# top-n
# 5                                               0.001010
# 10                                              0.001157
# 20                                              0.001101
#
# type                                                          \
# model ALS_rank-10_regularization-0.1_alpha-100_num_epochs-15
# top-n
# 5                                               0.000662
# 10                                              0.000776
# 20                                              0.000785
#
# type                                                          \
# model ALS_rank-10_regularization-0.1_alpha-100_num_epochs-30
# top-n
# 5                                               0.000715
# 10                                              0.000875
# 20                                              0.000926
#
# type                                                          \
# model ALS_rank-10_regularization-0.1_alpha-100_num_epochs-40
# top-n
# 5                                               0.000734
# 10                                              0.000895
# 20                                              0.000924
#
# type                                                        \
# model ALS_rank-10_regularization-0.1_alpha-1_num_epochs-15
# top-n
# 5                                               0.001146
# 10                                              0.001477
# 20                                              0.001482
#
# type                                                        \
# model ALS_rank-10_regularization-0.1_alpha-1_num_epochs-30
# top-n
# 5                                               0.001260
# 10                                              0.001546
# 20                                              0.001525
#
# type                                                        \
# model ALS_rank-10_regularization-0.1_alpha-1_num_epochs-40
# top-n
# 5                                               0.001133
# 10                                              0.001457
# 20                                              0.001499
#
# type                                                         \
# model ALS_rank-10_regularization-0.1_alpha-50_num_epochs-15
# top-n
# 5                                               0.000872
# 10                                              0.000979
# 20                                              0.000991
#
# type                                                         \
# model ALS_rank-10_regularization-0.1_alpha-50_num_epochs-30
# top-n
# 5                                               0.000961
# 10                                              0.001131
# 20                                              0.001122
#
# type                                                         \
# model ALS_rank-10_regularization-0.1_alpha-50_num_epochs-40
# top-n
# 5                                               0.000944
# 10                                              0.001132
# 20                                              0.001116
#
# type                                                        \
# model ALS_rank-10_regularization-1_alpha-100_num_epochs-15
# top-n
# 5                                               0.000755
# 10                                              0.000860
# 20                                              0.000827
#
# type                                                        \
# model ALS_rank-10_regularization-1_alpha-100_num_epochs-30
# top-n
# 5                                               0.000726
# 10                                              0.000888
# 20                                              0.000899
#
# type                                                        \
# model ALS_rank-10_regularization-1_alpha-100_num_epochs-40
# top-n
# 5                                               0.000702
# 10                                              0.000896
# 20                                              0.000935
#
# type                                                      \
# model ALS_rank-10_regularization-1_alpha-1_num_epochs-15
# top-n
# 5                                               0.001146
# 10                                              0.001483
# 20                                              0.001506
#
# type                                                      \
# model ALS_rank-10_regularization-1_alpha-1_num_epochs-30
# top-n
# 5                                               0.001184
# 10                                              0.001483
# 20                                              0.001509
#
# type                                                      \
# model ALS_rank-10_regularization-1_alpha-1_num_epochs-40
# top-n
# 5                                               0.001233
# 10                                              0.001548
# 20                                              0.001512
#
# type                                                       \
# model ALS_rank-10_regularization-1_alpha-50_num_epochs-15
# top-n
# 5                                               0.000832
# 10                                              0.000982
# 20                                              0.000978
#
# type                                                       \
# model ALS_rank-10_regularization-1_alpha-50_num_epochs-30
# top-n
# 5                                               0.001016
# 10                                              0.001143
# 20                                              0.001116
#
# type                                                       \
# model ALS_rank-10_regularization-1_alpha-50_num_epochs-40
# top-n
# 5                                               0.000902
# 10                                              0.001097
# 20                                              0.001127
#
# type                                                           \
# model ALS_rank-50_regularization-0.01_alpha-100_num_epochs-15
# top-n
# 5                                               0.002005
# 10                                              0.002053
# 20                                              0.001838
#
# type                                                           \
# model ALS_rank-50_regularization-0.01_alpha-100_num_epochs-30
# top-n
# 5                                               0.002339
# 10                                              0.002483
# 20                                              0.002208
#
# type                                                           \
# model ALS_rank-50_regularization-0.01_alpha-100_num_epochs-40
# top-n
# 5                                               0.002519
# 10                                              0.002578
# 20                                              0.002335
#
# type                                                         \
# model ALS_rank-50_regularization-0.01_alpha-1_num_epochs-15
# top-n
# 5                                               0.002186
# 10                                              0.002343
# 20                                              0.002193
#
# type                                                         \
# model ALS_rank-50_regularization-0.01_alpha-1_num_epochs-30
# top-n
# 5                                               0.002270
# 10                                              0.002414
# 20                                              0.002288
#
# type                                                         \
# model ALS_rank-50_regularization-0.01_alpha-1_num_epochs-40
# top-n
# 5                                               0.002294
# 10                                              0.002472
# 20                                              0.002237
#
# type                                                          \
# model ALS_rank-50_regularization-0.01_alpha-50_num_epochs-15
# top-n
# 5                                               0.002409
# 10                                              0.002460
# 20                                              0.002191
#
# type                                                          \
# model ALS_rank-50_regularization-0.01_alpha-50_num_epochs-30
# top-n
# 5                                               0.002689
# 10                                              0.002735
# 20                                              0.002495
#
# type                                                          \
# model ALS_rank-50_regularization-0.01_alpha-50_num_epochs-40
# top-n
# 5                                               0.002911
# 10                                              0.002911
# 20                                              0.002684
#
# type                                                          \
# model ALS_rank-50_regularization-0.1_alpha-100_num_epochs-15
# top-n
# 5                                               0.001914
# 10                                              0.001965
# 20                                              0.001768
#
# type                                                          \
# model ALS_rank-50_regularization-0.1_alpha-100_num_epochs-30
# top-n
# 5                                               0.002275
# 10                                              0.002375
# 20                                              0.002162
#
# type                                                          \
# model ALS_rank-50_regularization-0.1_alpha-100_num_epochs-40
# top-n
# 5                                               0.002419
# 10                                              0.002550
# 20                                              0.002326
#
# type                                                        \
# model ALS_rank-50_regularization-0.1_alpha-1_num_epochs-15
# top-n
# 5                                               0.002168
# 10                                              0.002312
# 20                                              0.002207
#
# type                                                        \
# model ALS_rank-50_regularization-0.1_alpha-1_num_epochs-30
# top-n
# 5                                               0.002287
# 10                                              0.002406
# 20                                              0.002311
#
# type                                                        \
# model ALS_rank-50_regularization-0.1_alpha-1_num_epochs-40
# top-n
# 5                                               0.002279
# 10                                              0.002417
# 20                                              0.002258
#
# type                                                         \
# model ALS_rank-50_regularization-0.1_alpha-50_num_epochs-15
# top-n
# 5                                               0.002355
# 10                                              0.002381
# 20                                              0.002183
#
# type                                                         \
# model ALS_rank-50_regularization-0.1_alpha-50_num_epochs-30
# top-n
# 5                                               0.002862
# 10                                              0.002935
# 20                                              0.002637
#
# type                                                         \
# model ALS_rank-50_regularization-0.1_alpha-50_num_epochs-40
# top-n
# 5                                               0.003005
# 10                                              0.002943
# 20                                              0.002640
#
# type                                                        \
# model ALS_rank-50_regularization-1_alpha-100_num_epochs-15
# top-n
# 5                                               0.001759
# 10                                              0.001825
# 20                                              0.001709
#
# type                                                        \
# model ALS_rank-50_regularization-1_alpha-100_num_epochs-30
# top-n
# 5                                               0.002442
# 10                                              0.002407
# 20                                              0.002178
#
# type                                                        \
# model ALS_rank-50_regularization-1_alpha-100_num_epochs-40
# top-n
# 5                                               0.002485
# 10                                              0.002550
# 20                                              0.002331
#
# type                                                      \
# model ALS_rank-50_regularization-1_alpha-1_num_epochs-15
# top-n
# 5                                               0.002185
# 10                                              0.002367
# 20                                              0.002209
#
# type                                                      \
# model ALS_rank-50_regularization-1_alpha-1_num_epochs-30
# top-n
# 5                                               0.002292
# 10                                              0.002409
# 20                                              0.002264
#
# type                                                      \
# model ALS_rank-50_regularization-1_alpha-1_num_epochs-40
# top-n
# 5                                               0.002175
# 10                                              0.002372
# 20                                              0.002264
#
# type                                                       \
# model ALS_rank-50_regularization-1_alpha-50_num_epochs-15
# top-n
# 5                                               0.002408
# 10                                              0.002406
# 20                                              0.002175
#
# type                                                       \
# model ALS_rank-50_regularization-1_alpha-50_num_epochs-30
# top-n
# 5                                               0.002746
# 10                                              0.002786
# 20                                              0.002526
#
# type                                                                           \
# model ALS_rank-50_regularization-1_alpha-50_num_epochs-40        MP   PureSVD
# top-n
# 5                                               0.002892   0.001445  0.001447
# 10                                              0.002898   0.001294  0.001358
# 20                                              0.002612   0.001582  0.001128
#
# type
# model       RND
# top-n
# 5      0.000015
# 10     0.000017
# 20     0.000024

# %%
#precisions_1.iloc[precisions_1.index.get_level_values('top-n') == 5]

# %% [markdown]
# Max precision values:

# %%
print(precisions_1.idxmax(axis=1)[5])
print(precisions_1.iloc[precisions_1.index.get_level_values('top-n') == 5].max(axis=1))
# Out:
# ('relevance', 'ALS_rank-100_regularization-0.01_alpha-50_num_epochs-40')
# top-n
# 5    0.003656
# dtype: float64

# %%
print(precisions_1.idxmax(axis=1)[10])
print(precisions_1.iloc[precisions_1.index.get_level_values('top-n') == 10].max(axis=1))
# Out:
# ('relevance', 'ALS_rank-100_regularization-0.01_alpha-50_num_epochs-40')
# top-n
# 10    0.002915
# dtype: float64

# %%
print(precisions_1.idxmax(axis=1)[20])
print(precisions_1.iloc[precisions_1.index.get_level_values('top-n') == 20].max(axis=1))
# Out:
# ('relevance', 'ALS_rank-100_regularization-0.01_alpha-50_num_epochs-40')
# top-n
# 20    0.002229
# dtype: float64

# %% [markdown]
# Max F1 score:

# %%
print(f1_scores_1.idxmax(axis=1)[5])
print(f1_scores_1.iloc[f1_scores_1.index.get_level_values('top-n') == 5].max(axis=1))
# Out:
# ('relevance', 'ALS_rank-100_regularization-0.01_alpha-50_num_epochs-40')
# top-n
# 5    0.00457
# dtype: float64

# %% [markdown]
# ## Analysis of second results

# %% [markdown]
# Results:

# %%
precisions_2 = scores_2.xs('precision', level='metric', axis=1).unstack('model')
precisions_2
# Out:
# type                             relevance  \
# model ALS_rank-100_alpha-100_num_epochs-40
# top-n
# 5                                 0.003394
# 10                                0.002673
# 20                                0.002069
#
# type                                        \
# model ALS_rank-100_alpha-100_num_epochs-50
# top-n
# 5                                 0.003351
# 10                                0.002717
# 20                                0.002095
#
# type                                        \
# model ALS_rank-100_alpha-100_num_epochs-60
# top-n
# 5                                 0.003400
# 10                                0.002771
# 20                                0.002114
#
# type                                        \
# model ALS_rank-150_alpha-100_num_epochs-40
# top-n
# 5                                 0.004386
# 10                                0.003450
# 20                                0.002522
#
# type                                        \
# model ALS_rank-150_alpha-100_num_epochs-50
# top-n
# 5                                 0.004430
# 10                                0.003500
# 20                                0.002601
#
# type                                        \
# model ALS_rank-150_alpha-100_num_epochs-60
# top-n
# 5                                 0.004364
# 10                                0.003462
# 20                                0.002645
#
# type                                        \
# model ALS_rank-200_alpha-100_num_epochs-40
# top-n
# 5                                 0.004997
# 10                                0.003854
# 20                                0.002864
#
# type                                        \
# model ALS_rank-200_alpha-100_num_epochs-50
# top-n
# 5                                 0.005050
# 10                                0.003956
# 20                                0.002932
#
# type
# model ALS_rank-200_alpha-100_num_epochs-60        MP   PureSVD       RND
# top-n
# 5                                 0.005075  0.001156  0.001158  0.000012
# 10                                0.003982  0.000841  0.000883  0.000012
# 20                                0.002971  0.000909  0.000648  0.000011

# %%
recalls_2 = scores_2.xs('recall', level='metric', axis=1).unstack('model')
recalls_2
# Out:
# type                             relevance  \
# model ALS_rank-100_alpha-100_num_epochs-40
# top-n
# 5                                 0.005656
# 10                                0.008909
# 20                                0.013794
#
# type                                        \
# model ALS_rank-100_alpha-100_num_epochs-50
# top-n
# 5                                 0.005585
# 10                                0.009058
# 20                                0.013965
#
# type                                        \
# model ALS_rank-100_alpha-100_num_epochs-60
# top-n
# 5                                 0.005666
# 10                                0.009237
# 20                                0.014091
#
# type                                        \
# model ALS_rank-150_alpha-100_num_epochs-40
# top-n
# 5                                 0.007310
# 10                                0.011501
# 20                                0.016815
#
# type                                        \
# model ALS_rank-150_alpha-100_num_epochs-50
# top-n
# 5                                 0.007384
# 10                                0.011665
# 20                                0.017339
#
# type                                        \
# model ALS_rank-150_alpha-100_num_epochs-60
# top-n
# 5                                 0.007273
# 10                                0.011539
# 20                                0.017636
#
# type                                        \
# model ALS_rank-200_alpha-100_num_epochs-40
# top-n
# 5                                 0.008329
# 10                                0.012848
# 20                                0.019091
#
# type                                        \
# model ALS_rank-200_alpha-100_num_epochs-50
# top-n
# 5                                 0.008417
# 10                                0.013186
# 20                                0.019545
#
# type
# model ALS_rank-200_alpha-100_num_epochs-60        MP   PureSVD       RND
# top-n
# 5                                 0.008458  0.001927  0.001929  0.000020
# 10                                0.013274  0.002804  0.002943  0.000040
# 20                                0.019808  0.006063  0.004323  0.000076

# %%
f1_scores_2 = f1_score(precisions_2, recalls_2)
f1_scores_2
# Out:
# type                             relevance  \
# model ALS_rank-100_alpha-100_num_epochs-40
# top-n
# 5                                 0.004242
# 10                                0.004112
# 20                                0.003598
#
# type                                        \
# model ALS_rank-100_alpha-100_num_epochs-50
# top-n
# 5                                 0.004189
# 10                                0.004180
# 20                                0.003643
#
# type                                        \
# model ALS_rank-100_alpha-100_num_epochs-60
# top-n
# 5                                 0.004250
# 10                                0.004263
# 20                                0.003676
#
# type                                        \
# model ALS_rank-150_alpha-100_num_epochs-40
# top-n
# 5                                 0.005483
# 10                                0.005308
# 20                                0.004386
#
# type                                        \
# model ALS_rank-150_alpha-100_num_epochs-50
# top-n
# 5                                 0.005538
# 10                                0.005384
# 20                                0.004523
#
# type                                        \
# model ALS_rank-150_alpha-100_num_epochs-60
# top-n
# 5                                 0.005455
# 10                                0.005326
# 20                                0.004601
#
# type                                        \
# model ALS_rank-200_alpha-100_num_epochs-40
# top-n
# 5                                 0.006247
# 10                                0.005930
# 20                                0.004980
#
# type                                        \
# model ALS_rank-200_alpha-100_num_epochs-50
# top-n
# 5                                 0.006313
# 10                                0.006086
# 20                                0.005099
#
# type
# model ALS_rank-200_alpha-100_num_epochs-60        MP   PureSVD       RND
# top-n
# 5                                 0.006343  0.001445  0.001447  0.000015
# 10                                0.006127  0.001294  0.001358  0.000019
# 20                                0.005167  0.001582  0.001128  0.000020

# %% [markdown]
# Max precision values:

# %%
print(precisions_2.idxmax(axis=1)[5])
print(precisions_2.iloc[precisions_2.index.get_level_values('top-n') == 5].max(axis=1))
# Out:
# ('relevance', 'ALS_rank-200_alpha-100_num_epochs-60')
# top-n
# 5    0.005075
# dtype: float64

# %%
print(precisions_2.idxmax(axis=1)[10])
print(precisions_2.iloc[precisions_2.index.get_level_values('top-n') == 10].max(axis=1))
# Out:
# ('relevance', 'ALS_rank-200_alpha-100_num_epochs-60')
# top-n
# 10    0.003982
# dtype: float64

# %%
print(precisions_2.idxmax(axis=1)[20])
print(precisions_2.iloc[precisions_2.index.get_level_values('top-n') == 20].max(axis=1))
# Out:
# ('relevance', 'ALS_rank-200_alpha-100_num_epochs-60')
# top-n
# 20    0.002971
# dtype: float64

# %% [markdown]
# Max F1 score:

# %%
print(f1_scores_2.idxmax(axis=1)[5])
print(f1_scores_2.iloc[f1_scores_2.index.get_level_values('top-n') == 5].max(axis=1))
# Out:
# ('relevance', 'ALS_rank-200_alpha-100_num_epochs-60')
# top-n
# 5    0.006343
# dtype: float64

# %% [markdown]
# ### Alpha curve

# %%
alpha_diff_scores_rank_100 = scores_1.iloc[
    scores_1.index.get_level_values('model').isin(['ALS_rank-100_regularization-0.01_alpha-1_num_epochs-40',
                                                   'ALS_rank-100_regularization-0.01_alpha-50_num_epochs-40',
                                                   'ALS_rank-100_regularization-0.01_alpha-100_num_epochs-40'])
].xs('precision', level='metric', axis=1).unstack('model')

alpha_5_precisions_rank_100 = alpha_diff_scores_rank_100.iloc[alpha_diff_scores_rank_100.index.get_level_values('top-n') == 5].values.flatten()
alpha_10_precisions_rank_100 = alpha_diff_scores_rank_100.iloc[alpha_diff_scores_rank_100.index.get_level_values('top-n') == 10].values.flatten()
alpha_20_precisions_rank_100 = alpha_diff_scores_rank_100.iloc[alpha_diff_scores_rank_100.index.get_level_values('top-n') == 20].values.flatten()

alpha_diff_scores_rank_50 = scores_1.iloc[
    scores_1.index.get_level_values('model').isin(['ALS_rank-50_regularization-0.01_alpha-1_num_epochs-40',
                                                   'ALS_rank-50_regularization-0.01_alpha-50_num_epochs-40',
                                                   'ALS_rank-50_regularization-0.01_alpha-100_num_epochs-40'])
].xs('precision', level='metric', axis=1).unstack('model')

alpha_5_precisions_rank_50 = alpha_diff_scores_rank_50.iloc[alpha_diff_scores_rank_50.index.get_level_values('top-n') == 5].values.flatten()
alpha_10_precisions_rank_50 = alpha_diff_scores_rank_50.iloc[alpha_diff_scores_rank_50.index.get_level_values('top-n') == 10].values.flatten()
alpha_20_precisions_rank_50 = alpha_diff_scores_rank_50.iloc[alpha_diff_scores_rank_50.index.get_level_values('top-n') == 20].values.flatten()


alpha_diff_values = [1, 50, 100]

# %%
plt.figure(figsize=(15, 7))

plt.subplot(121)
plt.title('factors = 100, regularization = 0.01, epochs = 40')
plt.xlabel(r'$\alpha$', fontsize=14)
plt.ylabel('Precision@K', fontsize=14)
plt.plot(alpha_diff_values, alpha_5_precisions_rank_100)
plt.plot(alpha_diff_values, alpha_10_precisions_rank_100)
plt.plot(alpha_diff_values, alpha_20_precisions_rank_100)
plt.legend(['K = 5', 'K = 10', 'K = 20'], loc='upper left')

plt.subplot(122)
plt.title('factors = 50, regularization = 0.01, epochs = 40')
plt.xlabel(r'$\alpha$', fontsize=14)
plt.ylabel('Precision@K', fontsize=14)
plt.plot(alpha_diff_values, alpha_5_precisions_rank_50)
plt.plot(alpha_diff_values, alpha_10_precisions_rank_50)
plt.plot(alpha_diff_values, alpha_20_precisions_rank_50)
plt.legend(['K = 5', 'K = 10', 'K = 20'], loc='upper left')

plt.show()

# %% [markdown]
# ### Regularization curve

# %%
reg_diff_scores_rank_100 = scores_1.iloc[
    scores_1.index.get_level_values('model').isin(['ALS_rank-100_regularization-0.01_alpha-50_num_epochs-40',
                                                   'ALS_rank-100_regularization-0.1_alpha-50_num_epochs-40',
                                                   'ALS_rank-100_regularization-1_alpha-50_num_epochs-40'])
].xs('precision', level='metric', axis=1).unstack('model')

reg_5_precisions_rank_100 = reg_diff_scores_rank_100.iloc[reg_diff_scores_rank_100.index.get_level_values('top-n') == 5].values.flatten()
reg_10_precisions_rank_100 = reg_diff_scores_rank_100.iloc[reg_diff_scores_rank_100.index.get_level_values('top-n') == 10].values.flatten()
reg_20_precisions_rank_100 = reg_diff_scores_rank_100.iloc[reg_diff_scores_rank_100.index.get_level_values('top-n') == 20].values.flatten()

reg_diff_scores_rank_50 = scores_1.iloc[
    scores_1.index.get_level_values('model').isin(['ALS_rank-50_regularization-0.01_alpha-50_num_epochs-40',
                                                   'ALS_rank-50_regularization-0.1_alpha-50_num_epochs-40',
                                                   'ALS_rank-50_regularization-1_alpha-50_num_epochs-40'])
].xs('precision', level='metric', axis=1).unstack('model')

reg_5_precisions_rank_50 = reg_diff_scores_rank_50.iloc[reg_diff_scores_rank_50.index.get_level_values('top-n') == 5].values.flatten()
reg_10_precisions_rank_50 = reg_diff_scores_rank_50.iloc[reg_diff_scores_rank_50.index.get_level_values('top-n') == 10].values.flatten()
reg_20_precisions_rank_50 = reg_diff_scores_rank_50.iloc[reg_diff_scores_rank_50.index.get_level_values('top-n') == 20].values.flatten()


reg_diff_values = [0.01, 0.1, 1]

# %%
plt.figure(figsize=(15, 7))

plt.subplot(121)
plt.title(r'factors = 100, $\alpha$ = 50, epochs = 40')
plt.xlabel('Regularization', fontsize=14)
plt.ylabel('Precision@K', fontsize=14)
plt.plot(reg_diff_values, reg_5_precisions_rank_100)
plt.plot(reg_diff_values, reg_10_precisions_rank_100)
plt.plot(reg_diff_values, reg_20_precisions_rank_100)
plt.legend(['K = 5', 'K = 10', 'K = 20'], loc='upper left')

plt.subplot(122)
plt.title(r'factors = 50, $\alpha$ = 50, epochs = 40')
plt.xlabel('Regularization', fontsize=14)
plt.ylabel('Precision@K', fontsize=14)
plt.plot(reg_diff_values, reg_5_precisions_rank_50)
plt.plot(reg_diff_values, reg_10_precisions_rank_50)
plt.plot(reg_diff_values, reg_20_precisions_rank_50)
plt.legend(['K = 5', 'K = 10', 'K = 20'], loc='upper left')

plt.show()

# %% [markdown]
# As can be seen, regularization factor has no significant impact on the results.

# %% [markdown]
# SVD with more (200) factors shows little progress:

# %%
precisions_3 = scores_3.xs('precision', level='metric', axis=1).unstack('model')
precisions_3
# Out:
# type                                                 relevance            \
# model ALS_rank-200_regularization-0.01_alpha-100_num_epochs-60        MP
# top-n
# 5                                               0.005112        0.001156
# 10                                              0.003963        0.000841
# 20                                              0.002957        0.000909
#
# type
# model   PureSVD       RND
# top-n
# 5      0.001672  0.000008
# 10     0.001372  0.000011
# 20     0.001019  0.000011

# %%
print(precisions_3.idxmax(axis=1)[5])
print(precisions_3.iloc[precisions_3.index.get_level_values('top-n') == 5].max(axis=1))
# Out:
# ('relevance', 'ALS_rank-200_regularization-0.01_alpha-100_num_epochs-60')
# top-n
# 5    0.005112
# dtype: float64

# %% [markdown]
# More fine-grained parameter grid search on number of epochs and number of latent factors:

# %%
precisions_4 = scores_4.xs('precision', level='metric', axis=1).unstack('model')
precisions_4
# Out:
# type                                                 relevance  \
# model ALS_rank-100_regularization-0.01_alpha-50_num_epochs-100
# top-n
# 5                                               0.003645
# 10                                              0.002961
# 20                                              0.002269
#
# type                                                           \
# model ALS_rank-100_regularization-0.01_alpha-50_num_epochs-40
# top-n
# 5                                               0.003564
# 10                                              0.002883
# 20                                              0.002260
#
# type                                                           \
# model ALS_rank-100_regularization-0.01_alpha-50_num_epochs-60
# top-n
# 5                                               0.003596
# 10                                              0.002909
# 20                                              0.002256
#
# type                                                           \
# model ALS_rank-100_regularization-0.01_alpha-50_num_epochs-80
# top-n
# 5                                               0.003522
# 10                                              0.002914
# 20                                              0.002258
#
# type                                                            \
# model ALS_rank-150_regularization-0.01_alpha-50_num_epochs-100
# top-n
# 5                                               0.004675
# 10                                              0.003611
# 20                                              0.002767
#
# type                                                           \
# model ALS_rank-150_regularization-0.01_alpha-50_num_epochs-40
# top-n
# 5                                               0.004472
# 10                                              0.003546
# 20                                              0.002712
#
# type                                                           \
# model ALS_rank-150_regularization-0.01_alpha-50_num_epochs-60
# top-n
# 5                                               0.004603
# 10                                              0.003653
# 20                                              0.002733
#
# type                                                           \
# model ALS_rank-150_regularization-0.01_alpha-50_num_epochs-80
# top-n
# 5                                               0.004566
# 10                                              0.003562
# 20                                              0.002723
#
# type                                                            \
# model ALS_rank-200_regularization-0.01_alpha-50_num_epochs-100
# top-n
# 5                                               0.005176
# 10                                              0.004014
# 20                                              0.003005
#
# type                                                           \
# model ALS_rank-200_regularization-0.01_alpha-50_num_epochs-40
# top-n
# 5                                               0.005156
# 10                                              0.004056
# 20                                              0.003042
#
# type                                                           \
# model ALS_rank-200_regularization-0.01_alpha-50_num_epochs-60
# top-n
# 5                                               0.005132
# 10                                              0.004018
# 20                                              0.003040
#
# type                                                                     \
# model ALS_rank-200_regularization-0.01_alpha-50_num_epochs-80        MP
# top-n
# 5                                               0.005112       0.001156
# 10                                              0.004060       0.000841
# 20                                              0.003069       0.000909
#
# type
# model   PureSVD       RND
# top-n
# 5      0.001158  0.000012
# 10     0.000883  0.000019
# 20     0.000648  0.000017

# %% [markdown]
# Visualization of different precision values depending on number of epochs:

# %%
epochs_diff_scores_rank_100 = scores_4.iloc[
    scores_4.index.get_level_values('model').isin(['ALS_rank-100_regularization-0.01_alpha-50_num_epochs-40',
                                                   'ALS_rank-100_regularization-0.01_alpha-50_num_epochs-60',
                                                   'ALS_rank-100_regularization-0.01_alpha-50_num_epochs-80',
                                                   'ALS_rank-100_regularization-0.01_alpha-50_num_epochs-100'])
].xs('precision', level='metric', axis=1).unstack('model')

epochs_5_precisions_rank_100 = epochs_diff_scores_rank_100.iloc[epochs_diff_scores_rank_100.index.get_level_values('top-n') == 5].values.flatten()
epochs_10_precisions_rank_100 = epochs_diff_scores_rank_100.iloc[epochs_diff_scores_rank_100.index.get_level_values('top-n') == 10].values.flatten()
epochs_20_precisions_rank_100 = epochs_diff_scores_rank_100.iloc[epochs_diff_scores_rank_100.index.get_level_values('top-n') == 20].values.flatten()

epochs_diff_scores_rank_150 = scores_4.iloc[
    scores_4.index.get_level_values('model').isin(['ALS_rank-150_regularization-0.01_alpha-50_num_epochs-40',
                                                   'ALS_rank-150_regularization-0.01_alpha-50_num_epochs-60',
                                                   'ALS_rank-150_regularization-0.01_alpha-50_num_epochs-80',
                                                   'ALS_rank-150_regularization-0.01_alpha-50_num_epochs-100'])
].xs('precision', level='metric', axis=1).unstack('model')

epochs_5_precisions_rank_150 = epochs_diff_scores_rank_150.iloc[epochs_diff_scores_rank_150.index.get_level_values('top-n') == 5].values.flatten()
epochs_10_precisions_rank_150 = epochs_diff_scores_rank_150.iloc[epochs_diff_scores_rank_150.index.get_level_values('top-n') == 10].values.flatten()
epochs_20_precisions_rank_150 = epochs_diff_scores_rank_150.iloc[epochs_diff_scores_rank_150.index.get_level_values('top-n') == 20].values.flatten()

epochs_diff_scores_rank_200 = scores_4.iloc[
    scores_4.index.get_level_values('model').isin(['ALS_rank-200_regularization-0.01_alpha-50_num_epochs-40',
                                                   'ALS_rank-200_regularization-0.01_alpha-50_num_epochs-60',
                                                   'ALS_rank-200_regularization-0.01_alpha-50_num_epochs-80',
                                                   'ALS_rank-200_regularization-0.01_alpha-50_num_epochs-100'])
].xs('precision', level='metric', axis=1).unstack('model')

epochs_5_precisions_rank_200 = epochs_diff_scores_rank_200.iloc[epochs_diff_scores_rank_200.index.get_level_values('top-n') == 5].values.flatten()
epochs_10_precisions_rank_200 = epochs_diff_scores_rank_200.iloc[epochs_diff_scores_rank_200.index.get_level_values('top-n') == 10].values.flatten()
epochs_20_precisions_rank_200 = epochs_diff_scores_rank_200.iloc[epochs_diff_scores_rank_200.index.get_level_values('top-n') == 20].values.flatten()

epochs_diff_values = [40, 60, 80, 100]

# %%
plt.figure(figsize=(22, 7))

plt.subplot(131)
plt.title(r'factors = 100, $\alpha$ = 50, regularization = 0.01')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Precision@K', fontsize=14)
plt.plot(epochs_diff_values, epochs_5_precisions_rank_100)
plt.plot(epochs_diff_values, epochs_10_precisions_rank_100)
plt.plot(epochs_diff_values, epochs_20_precisions_rank_100)
plt.legend(['K = 5', 'K = 10', 'K = 20'], loc='upper left')

plt.subplot(132)
plt.title(r'factors = 150, $\alpha$ = 50, regularization = 0.01')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Precision@K', fontsize=14)
plt.plot(epochs_diff_values, epochs_5_precisions_rank_150)
plt.plot(epochs_diff_values, epochs_10_precisions_rank_150)
plt.plot(epochs_diff_values, epochs_20_precisions_rank_150)
plt.legend(['K = 5', 'K = 10', 'K = 20'], loc='upper left')

plt.subplot(133)
plt.title(r'factors = 200, $\alpha$ = 50, regularization = 0.01')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Precision@K', fontsize=14)
plt.plot(epochs_diff_values, epochs_5_precisions_rank_200)
plt.plot(epochs_diff_values, epochs_10_precisions_rank_200)
plt.plot(epochs_diff_values, epochs_20_precisions_rank_200)
plt.legend(['K = 5', 'K = 10', 'K = 20'], loc='upper left')

plt.show()

# %%
factors_diff_scores_epochs_40 = scores_4.iloc[
    scores_4.index.get_level_values('model').isin(['ALS_rank-100_regularization-0.01_alpha-50_num_epochs-40',
                                                   'ALS_rank-150_regularization-0.01_alpha-50_num_epochs-40',
                                                   'ALS_rank-200_regularization-0.01_alpha-50_num_epochs-40'])
].xs('precision', level='metric', axis=1).unstack('model')

factors_5_precisions_epochs_40 = factors_diff_scores_epochs_40.iloc[factors_diff_scores_epochs_40.index.get_level_values('top-n') == 5].values.flatten()
factors_10_precisions_epochs_40 = factors_diff_scores_epochs_40.iloc[factors_diff_scores_epochs_40.index.get_level_values('top-n') == 10].values.flatten()
factors_20_precisions_epochs_40 = factors_diff_scores_epochs_40.iloc[factors_diff_scores_epochs_40.index.get_level_values('top-n') == 20].values.flatten()

factors_diff_scores_epochs_60 = scores_4.iloc[
    scores_4.index.get_level_values('model').isin(['ALS_rank-100_regularization-0.01_alpha-50_num_epochs-60',
                                                   'ALS_rank-150_regularization-0.01_alpha-50_num_epochs-60',
                                                   'ALS_rank-200_regularization-0.01_alpha-50_num_epochs-60'])
].xs('precision', level='metric', axis=1).unstack('model')

factors_5_precisions_epochs_60 = factors_diff_scores_epochs_60.iloc[factors_diff_scores_epochs_60.index.get_level_values('top-n') == 5].values.flatten()
factors_10_precisions_epochs_60 = factors_diff_scores_epochs_60.iloc[factors_diff_scores_epochs_60.index.get_level_values('top-n') == 10].values.flatten()
factors_20_precisions_epochs_60 = factors_diff_scores_epochs_60.iloc[factors_diff_scores_epochs_60.index.get_level_values('top-n') == 20].values.flatten()

factors_diff_scores_epochs_80 = scores_4.iloc[
    scores_4.index.get_level_values('model').isin(['ALS_rank-100_regularization-0.01_alpha-50_num_epochs-80',
                                                   'ALS_rank-150_regularization-0.01_alpha-50_num_epochs-80',
                                                   'ALS_rank-200_regularization-0.01_alpha-50_num_epochs-80'])
].xs('precision', level='metric', axis=1).unstack('model')

factors_5_precisions_epochs_80 = factors_diff_scores_epochs_80.iloc[factors_diff_scores_epochs_80.index.get_level_values('top-n') == 5].values.flatten()
factors_10_precisions_epochs_80 = factors_diff_scores_epochs_80.iloc[factors_diff_scores_epochs_80.index.get_level_values('top-n') == 10].values.flatten()
factors_20_precisions_epochs_80 = factors_diff_scores_epochs_80.iloc[factors_diff_scores_epochs_80.index.get_level_values('top-n') == 20].values.flatten()

factors_diff_values = [100, 150, 200]

# %%
plt.figure(figsize=(22, 7))

plt.subplot(131)
plt.title(r'epochs = 100, $\alpha$ = 50, regularization = 0.01')
plt.xlabel('Factors', fontsize=14)
plt.ylabel('Precision@K', fontsize=14)
plt.plot(factors_diff_values, factors_5_precisions_epochs_40)
plt.plot(factors_diff_values, factors_10_precisions_epochs_40)
plt.plot(factors_diff_values, factors_20_precisions_epochs_40)
plt.legend(['K = 5', 'K = 10', 'K = 20'], loc='upper left')

plt.subplot(132)
plt.title(r'epochs = 150, $\alpha$ = 50, regularization = 0.01')
plt.xlabel('Factors', fontsize=14)
plt.ylabel('Precision@K', fontsize=14)
plt.plot(factors_diff_values, factors_5_precisions_epochs_60)
plt.plot(factors_diff_values, factors_10_precisions_epochs_60)
plt.plot(factors_diff_values, factors_20_precisions_epochs_60)
plt.legend(['K = 5', 'K = 10', 'K = 20'], loc='upper left')

plt.subplot(133)
plt.title(r'epochs = 200, $\alpha$ = 50, regularization = 0.01')
plt.xlabel('Factors', fontsize=14)
plt.ylabel('Precision@K', fontsize=14)
plt.plot(factors_diff_values, factors_5_precisions_epochs_80)
plt.plot(factors_diff_values, factors_10_precisions_epochs_80)
plt.plot(factors_diff_values, factors_20_precisions_epochs_80)
plt.legend(['K = 5', 'K = 10', 'K = 20'], loc='upper left')

plt.show()
